# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
cars = pd.read_csv('./craigslistVehicles.csv')
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
cars.sample(5)
# Out:
#                                                       url  \
# 31873   https://spacecoast.craigslist.org/ctd/d/titusv...
# 400329  https://raleigh.craigslist.org/ctd/d/four-oaks...
# 79589   https://bend.craigslist.org/ctd/d/redmond-2010...
# 48281   https://albuquerque.craigslist.org/cto/d/albuq...
# 73183   https://batonrouge.craigslist.org/ctd/d/baton-...
#
#                          city                            city_url  price  \
# 31873         space coast, FL   https://spacecoast.craigslist.org   9999
# 400329  raleigh / durham / CH      https://raleigh.craigslist.org      0
# 79589                bend, OR         https://bend.craigslist.org      0
# 48281             albuquerque  https://albuquerque.craigslist.org   6550
# 73183             baton rouge   https://batonrouge.craigslist.org   8995
#
#           year manufacturer             make  condition    cylinders fuel  \
# 31873   2012.0      hyundai           sonata  excellent  4 cylinders  gas
# ...

# %%
cars['price'].mean()
# Out:
# 93987.72793301266

# %%
cars[cars['price'] == 0]
# Out:
#                                                       url               city  \
# 63      https://albanyga.craigslist.org/ctd/d/tifton-2...         albany, GA
# 64      https://albanyga.craigslist.org/ctd/d/tifton-2...         albany, GA
# 65      https://albanyga.craigslist.org/ctd/d/tifton-2...         albany, GA
# 66      https://albanyga.craigslist.org/ctd/d/tifton-2...         albany, GA
# 68      https://albanyga.craigslist.org/ctd/d/tifton-2...         albany, GA
# 74      https://albanyga.craigslist.org/ctd/d/tifton-2...         albany, GA
# 75      https://albanyga.craigslist.org/ctd/d/tifton-2...         albany, GA
# 79      https://albanyga.craigslist.org/ctd/d/tifton-2...         albany, GA
# 80      https://albanyga.craigslist.org/ctd/d/tifton-2...         albany, GA
# 81      https://albanyga.craigslist.org/ctd/d/tifton-2...         albany, GA
# 82      https://albanyga.craigslist.org/ctd/d/tifton-2...         albany, GA
# ...

# %%
cars.describe()
# Out:
#               price           year      odometer            lat           long
# count  5.503130e+05  548826.000000  4.395130e+05  538523.000000  538523.000000
# mean   9.398773e+04    2008.709121  1.037676e+05      38.446760     -93.849082
# std    1.242762e+07       9.610097  2.126622e+05       5.822595      17.611870
# min    0.000000e+00    1900.000000  0.000000e+00     -81.884981    -178.154297
# 25%    3.790000e+03    2006.000000  5.057600e+04      34.724400    -106.369340
# 50%    8.988000e+03    2011.000000  9.648300e+04      39.124000     -88.160859
# 75%    1.750000e+04    2015.000000  1.400480e+05      42.389954     -80.801896
# max    3.787877e+09    2020.000000  1.021028e+08      84.151686     122.367000

# %%
cars[cars['city'].str.contains('CA')].price.mean() #average car prices in California
# Out:
# 12711.535157277613

# %%
cars[cars['city'].str.contains('TX')].price.mean() # average prices in texas
# Out:
# 80234.36148879206

# %%
cars.odometer.mean() #average milage on a car # time for a new car
# Out:
# 103767.56989440585

# %%
cars.condition.isnull().sum()
# Out:
# 250074

# %%
cars[cars['condition'] == 'excellent']
cars.condition.describe()
# Out:
# count        300239
# unique            6
# top       excellent
# freq         143773
# Name: condition, dtype: object

# %%
sampled_cars = cars.sample(1000)

# %%
sampled_cars[sampled_cars['city'].str.contains('CA')].price.mean() # out of 1000 sampeld cars
# Out:
# 14260.533333333333

# %%
sampled_cars[sampled_cars['city'].str.contains('TX')].price.mean() # out of 1000 sampeld cars
# Out:
# 19381.869565217392

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()

    
# sampled_cars[sampled_cars.year.isnull()]
sampled_cars.dropna(inplace=True) # delete all rows with N/A or null values
# sampled_cars.shape # now down to 129 samples
sampled_cars['year'].astype('int64')


X = sampled_cars[['year']]
y = sampled_cars.price

linreg.fit(X, y);

# %%
y_pred = linreg.predict(X)
sampled_cars['y_pred'] = y_pred

# %%
plt.plot(sampled_cars.year , sampled_cars.y_pred) # evaluate year car is made in with price

# %%
plt.scatter(sampled_cars.year , sampled_cars.price)
plt.plot(sampled_cars.year , sampled_cars.y_pred, color='red')
plt.xlabel('year')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
sampled_cars['odometer'].astype('int64')

X = sampled_cars[['odometer']]
y = sampled_cars.price

linreg.fit(X, y);

# %%
y_pred = linreg.predict(X)
sampled_cars['y_pred'] = y_pred

# %%
plt.plot(sampled_cars.odometer , sampled_cars.y_pred) # price go down as odo goes up

# %%
plt.scatter(sampled_cars.odometer , sampled_cars.price)
plt.plot(sampled_cars.odometer , sampled_cars.y_pred, color='red')
plt.xlabel('odometer')
plt.ylabel('price')
# Out:
# Text(0, 0.5, 'price')

# %%
sns.heatmap(sampled_cars.corr()) #y_pred is expected price(value)Y test

# %%
linreg.coef_
# Out:
# array([-0.05901039])

# %%
linreg.intercept_
# Out:
# 18135.067415139143

# %%
sns.heatmap(cars.corr()) #too many data ? doesnot have a negative avlue

# %%
car_year = sampled_cars.year 
car_odometer = sampled_cars.odometer
plt.plot(car_year , car_odometer)
plt.show() #what??
